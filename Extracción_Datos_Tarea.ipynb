# %%
pip install seaborn
# Out:
# ...
#
# ...

# %%
#Importamos librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip install openpyxl
# Out:
# ...
#
# ...

# %%
df = pd.read_excel("Detalle precios y productos fabricados 2022.xlsx")
df
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL     1      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 2        ANA BARBARA CRUZ PALACIOS     7        TP0007
# 3             OMAR RODRIGUEZ GOMEZ     1        TP0001
# 4               PÚBLICO EN GENERAL     2       BP00242
# ...

# %%
#Verificamos información del DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1426 entries, 0 to 1425
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CVE_DOC                    1426 non-null   object
#  1   FECHA_DOC                  1426 non-null   datetime64[ns]
#  2   NOMBRE_VENDEDOR            1424 non-null   object
#  3   NOMBRE_CLIENTE             1426 non-null   object
#  4   CANT                       1426 non-null   int64
#  5   CVE_ART                    1426 non-null   object
#  6   DESCR                      1426 non-null   object
#  7   PRECIO_UNITARIO            1426 non-null   float64
#  8   COSTO_UNITARIO             1426 non-null   float64
#  9   COSTO_UNITARIO_CALCULADO   1426 non-null   float64
#  10  SUBTOTAL_PARTIDA           1426 non-null   float64
#  11  COSTO_TOTAL_CALCULADO      1426 non-null   float64
#  12  MARGEN_UNITARIO_CALCULADO  1426 non-null   float64
# ...

# %%
#Imprimo los primeros 5 registro del dataframe
df.head(5)
# Out:
#   CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR                NOMBRE_CLIENTE  \
# 0  F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
# 1  F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ  JUAN ANTONIO RESENDIZ UGALDE
# 2  F37041 2022-01-05   DIEGO ARMANDO LEON DURAN     ANA BARBARA CRUZ PALACIOS
# 3  F37042 2022-01-05   DIEGO ARMANDO LEON DURAN          OMAR RODRIGUEZ GOMEZ
# 4  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
#
#    CANT   CVE_ART                                    DESCR  PRECIO_UNITARIO  \
# 0     1  TUE00244  TUB COBRE 5/16"ØX165MM CIRCULA1.5KW127V           434.48
# 1     1  TUA00028  TUA U" 5/16 ØX250MM 1200W 120V TAP1"NPT          1264.05
# 2     7    TP0007     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 7 MT           551.61
# 3     1    TP0001     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 1 MT           140.00
# 4     2   BP00242  BAN P INOX 115MMX235MM 1000W 127V T/TOR           172.41
#
# ...

# %%
#Filtro por objeto
filtro1=df[df["NOMBRE_VENDEDOR"] == "LETICIA RAMIREZ HERNANDEZ"]
filtro1
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 5     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 7     F37046 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1416  F39830 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL     1      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 4               PÚBLICO EN GENERAL     2       BP00242
# 5               PÚBLICO EN GENERAL     2       BP00243
# 7        ANA BARBARA CRUZ PALACIOS     3        TP0001
# ...

# %%
#Filtro por filas
#filtro2= df.iloc[3:10,: ]           #Filas consecutivas
filtro2=df.iloc[ [8, 24, 100] , : ]  #Filas no consecutivas
filtro2
# Out:
#     CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 8    F37048 2022-01-05   DIEGO ARMANDO LEON DURAN
# 24   F37069 2022-01-07         AARON NUÑO CORDOVA
# 100  F37223 2022-01-28  LETICIA RAMIREZ HERNANDEZ
#
#                                        NOMBRE_CLIENTE  CANT   CVE_ART  \
# 8                                  FIDEICOMISO F/1596     1  TUE00207
# 24                                  ADVANEX DE MEXICO     2   RP00150
# 100  COMPONENTES ELECTRICOS Y DISPOSITIVOS ESPECIALES     1    TP0025
#
#                                         DESCR  PRECIO_UNITARIO  \
# 8    TUB INCOLOY 1/2"Øx412mm J 9KW 240V PLACA           1615.0
# 24                     REPARACION DE TERMOPAR           1500.0
# 100    TERMOPAR K 3/16Ø  X 1'  1/2 EXT. 2 MT"            175.0
#
#      COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  SUBTOTAL_PARTIDA  \
# 8            517.89                    517.89            1615.0
# 24             0.36                      0.36            3000.0
# ...

# %%
#Filtro por columnas
filtro3=df.iloc[ : , 1:3]       #Columnas consecutivas
#filtro3=df.iloc[ : , [1,4,6]]  #Columnas no consecutivas
filtro3
# Out:
#       FECHA_DOC            NOMBRE_VENDEDOR
# 0    2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1    2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2    2022-01-05   DIEGO ARMANDO LEON DURAN
# 3    2022-01-05   DIEGO ARMANDO LEON DURAN
# 4    2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...         ...                        ...
# 1421 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425 2022-12-23         AARON NUÑO CORDOVA
#
# [1426 rows x 2 columns]

# %%
df1 = pd.read_excel("Detalle precios y productos fabricados 2022.xlsx", index_col=1)
df1
# Out:
#            CVE_DOC            NOMBRE_VENDEDOR                NOMBRE_CLIENTE  \
# FECHA_DOC
# 2022-01-05  F37034  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
# 2022-01-05  F37036  LETICIA RAMIREZ HERNANDEZ  JUAN ANTONIO RESENDIZ UGALDE
# 2022-01-05  F37041   DIEGO ARMANDO LEON DURAN     ANA BARBARA CRUZ PALACIOS
# 2022-01-05  F37042   DIEGO ARMANDO LEON DURAN          OMAR RODRIGUEZ GOMEZ
# 2022-01-05  F37043  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
# ...            ...                        ...                           ...
# 2022-12-23  F39834  LETICIA RAMIREZ HERNANDEZ     LUIS ENRIQUE PATIÑO PEREZ
# 2022-12-23  F39834  LETICIA RAMIREZ HERNANDEZ     LUIS ENRIQUE PATIÑO PEREZ
# 2022-12-23  F39835  LETICIA RAMIREZ HERNANDEZ          SEVEN DAYS ALL SPORT
# 2022-12-23  F39837  LETICIA RAMIREZ HERNANDEZ           REVUELTA MONTECARLO
# 2022-12-23  F39838         AARON NUÑO CORDOVA                CPEG SOLUTIONS
#
# ...

# %%
print(df1.index)    # Verifica las etiquetas de filas
print(df1.columns)  # Verifica las etiquetas de columnas
# Out:
# DatetimeIndex(['2022-01-05', '2022-01-05', '2022-01-05', '2022-01-05',
#                '2022-01-05', '2022-01-05', '2022-01-05', '2022-01-05',
#                '2022-01-05', '2022-01-05',
#                ...
#                '2022-12-23', '2022-12-23', '2022-12-23', '2022-12-23',
#                '2022-12-23', '2022-12-23', '2022-12-23', '2022-12-23',
#                '2022-12-23', '2022-12-23'],
#               dtype='datetime64[ns]', name='FECHA_DOC', length=1426, freq=None)
# Index(['CVE_DOC', 'NOMBRE_VENDEDOR', 'NOMBRE_CLIENTE', 'CANT', 'CVE_ART',
#        'DESCR', 'PRECIO_UNITARIO', 'COSTO_UNITARIO',
#        'COSTO_UNITARIO_CALCULADO', 'SUBTOTAL_PARTIDA', 'COSTO_TOTAL_CALCULADO',
#        'MARGEN_UNITARIO_CALCULADO', 'MARGEN_TOTAL_CALCULADO'],
#       dtype='object')

# %%
#Paso 2: Aplicamos Filtro de filas vs columnas
filtro4=df1.loc[['2022-12-23' ,'2022-01-05'], ['NOMBRE_VENDEDOR','COSTO_UNITARIO']]
filtro4
# Out:
#                       NOMBRE_VENDEDOR  COSTO_UNITARIO
# FECHA_DOC
# 2022-12-23             ALFREDO CANELA         4579.08
# 2022-12-23         AARON NUÑO CORDOVA           78.09
# 2022-12-23  LETICIA RAMIREZ HERNANDEZ           51.16
# 2022-12-23  LETICIA RAMIREZ HERNANDEZ            0.00
# 2022-12-23  LETICIA RAMIREZ HERNANDEZ            0.00
# 2022-12-23         AARON NUÑO CORDOVA           65.31
# 2022-12-23         AARON NUÑO CORDOVA          286.13
# 2022-12-23         AARON NUÑO CORDOVA          421.91
# 2022-12-23         AARON NUÑO CORDOVA          477.16
# 2022-12-23  LETICIA RAMIREZ HERNANDEZ          102.31
# 2022-12-23  LETICIA RAMIREZ HERNANDEZ          104.69
# 2022-12-23  LETICIA RAMIREZ HERNANDEZ            0.00
# 2022-12-23  LETICIA RAMIREZ HERNANDEZ         1884.35
# 2022-12-23         AARON NUÑO CORDOVA            0.00
# 2022-01-05  LETICIA RAMIREZ HERNANDEZ           52.80
# 2022-01-05  LETICIA RAMIREZ HERNANDEZ          327.18
# ...

# %%
#Filtro por cabecera
filtro5=df.head(10)
filtro5
# Out:
#   CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0  F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1  F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2  F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3  F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 5  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 6  F37044 2022-01-05   DIEGO ARMANDO LEON DURAN
# 7  F37046 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 8  F37048 2022-01-05   DIEGO ARMANDO LEON DURAN
# 9  F37049 2022-01-05   DIEGO ARMANDO LEON DURAN
#
#                         NOMBRE_CLIENTE  CANT   CVE_ART  \
# 0                   PÚBLICO EN GENERAL     1  TUE00244
# 1         JUAN ANTONIO RESENDIZ UGALDE     1  TUA00028
# 2            ANA BARBARA CRUZ PALACIOS     7    TP0007
# 3                 OMAR RODRIGUEZ GOMEZ     1    TP0001
# 4                   PÚBLICO EN GENERAL     2   BP00242
# 5                   PÚBLICO EN GENERAL     2   BP00243
# ...

# %%
#Filtro por comparacion
filtro6=df[df["COSTO_UNITARIO"] > 1000]
filtro6
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 6     F37044 2022-01-05   DIEGO ARMANDO LEON DURAN
# 25    F37071 2022-01-07   DIEGO ARMANDO LEON DURAN
# 102   F37230 2022-01-31             ALFREDO CANELA
# 103   F37231 2022-01-31             ALFREDO CANELA
# 177   F37378 2022-02-16   DIEGO ARMANDO LEON DURAN
# ...      ...        ...                        ...
# 1323  F39627 2022-11-24  LETICIA RAMIREZ HERNANDEZ
# 1360  F39716 2022-12-07             ALFREDO CANELA
# 1389  F39776 2022-12-15             ALFREDO CANELA
# 1412  F39824 2022-12-23             ALFREDO CANELA
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
#
#                                     NOMBRE_CLIENTE  CANT    CVE_ART  \
# 6              AIRBUS HELICOPTERS MEXICO QUERETARO     1    RP00165
# 25                 FRANCISCO JAVIER MEDINA SANCHEZ     3   TUA00009
# 102                                        DEACERO     2   54020219
# 103                                        DEACERO     2   93980461
# ...

# %%
#Filtro Y
filtro7=df[(df["PRECIO_UNITARIO"] > 1000) & (df["FECHA_DOC"] == "2022-01-31")]
filtro7
# Out:
#     CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 101  F37226 2022-01-31   DIEGO ARMANDO LEON DURAN
# 102  F37230 2022-01-31             ALFREDO CANELA
# 103  F37231 2022-01-31             ALFREDO CANELA
# 105  F37235 2022-01-31  LETICIA RAMIREZ HERNANDEZ
# 107  F37237 2022-01-31             ALFREDO CANELA
# 109  F37239 2022-01-31        ATENCION A CLIENTES
# 110  F37240 2022-01-31             ALFREDO CANELA
# 111  F37240 2022-01-31             ALFREDO CANELA
# 112  F37240 2022-01-31             ALFREDO CANELA
# 113  F37241 2022-01-31  LETICIA RAMIREZ HERNANDEZ
# 114  F37242 2022-01-31             ALFREDO CANELA
#
#                                    NOMBRE_CLIENTE  CANT   CVE_ART  \
# 101                                 SIKA MEXICANA     2   PT00082
# 102                                       DEACERO     2  54020219
# 103                                       DEACERO     2  93980461
# 105                       LIDIA BARRIOS HERNANDEZ     1  TUE00057
# ...

# %%
#Filtro o
filtro8=df[(df["PRECIO_UNITARIO"] < 1000) | (df["FECHA_DOC"] == "2022-01-31")]
filtro8
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 5     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1414  F39828 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1416  F39830 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1417  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
#
#                   NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0             PÚBLICO EN GENERAL     1      TUE00244
# 2      ANA BARBARA CRUZ PALACIOS     7        TP0007
# 3           OMAR RODRIGUEZ GOMEZ     1        TP0001
# 4             PÚBLICO EN GENERAL     2       BP00242
# 5             PÚBLICO EN GENERAL     2       BP00243
# ...

# %%
#Filtro not
filtro9=df[~(df["PRECIO_UNITARIO"] >= 1000) & ~(df["FECHA_DOC"] == "2022-01-31")]
filtro9
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 5     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1414  F39828 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1416  F39830 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1417  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
#
#                   NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0             PÚBLICO EN GENERAL     1      TUE00244
# 2      ANA BARBARA CRUZ PALACIOS     7        TP0007
# 3           OMAR RODRIGUEZ GOMEZ     1        TP0001
# 4             PÚBLICO EN GENERAL     2       BP00242
# 5             PÚBLICO EN GENERAL     2       BP00243
# ...

# %%
#Convertir archivo filtrado a CSV
filtro1.to_csv("Actividad 1.1_Filtro1")

# %%
#Convertir archivo filtrado a CSV
filtro2.to_csv("Actividad 1.1_Filtro2")

# %%
#Convertir archivo filtrado a CSV
filtro3.to_csv("Actividad 1.1_Filtro3")

# %%
#Convertir archivo filtrado a CSV
filtro4.to_csv("Actividad 1.1_Filtro4")

# %%
#Convertir archivo filtrado a CSV
filtro5.to_csv("Actividad 1.1_Filtro5")

# %%
#Convertir archivo filtrado a CSV
filtro6.to_csv("Actividad 1.1_Filtro6")

# %%
#Convertir archivo filtrado a CSV
filtro7.to_csv("Actividad 1.1_Filtro7")

# %%
#Convertir archivo filtrado a CSV
filtro8.to_csv("Actividad 1.1_Filtro8")

# %%
#Convertir archivo filtrado a CSV
filtro9.to_csv("Actividad 1.1_Filtro9")
